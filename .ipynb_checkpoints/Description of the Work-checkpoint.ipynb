# %% [markdown]
# First Step: Finishing up the Final Project

# %% [markdown]
# For this assignment, I first started with completing the missing pieces of my final assignment. I made sure that all of the descriptions on each park showed and that it did not show all parks on one page by limiting it to 25 per page. I made sure that it was clear to read by bolding the title. I also made sure that it had other pages to click on located on the top, such as about and contact. I chose to do this because a lot of websites have pages like this and this showed me how to do links correctly.

# %% [markdown]
# Second Step: Decide Where to Start

# %% [markdown]
# From the final project, I started building the portfolio. The first part is always looking at ways I could design it so I have a picture in my head instead of leading myself blind. I decided to go with a design like my Adobe Portfolio as I like the way it is formatted and it seemed like a more simple design that I could piece apart.

# %% [markdown]
# Third Step: Figuring Out How To Design What I Want and Can Use in the Future

# %% [markdown]
# I started with what I knew how to do from past assignments and things that I did as a graphic designer. I had a particularly challenging time with the box as I have never done this before and it would not work in past projects, including the final project. I did however want to learn how to do this so I looked up some examples from people online and their suggestions. Through a lot of trial and error, I got it to work after figuring out the margins and what padding is. I then changed some color patterns and design on the box.

# %% [markdown]
# Fourth Step: Imaging and Final Few Things

# %% [markdown]
# After this, I learned how to format a picture a little differently then what I learned in class because I had to be particular with the sizing and the location of the text. I wanted the title above and the link or description underneath. Finally, I checked to make sure every link worked from my final assignment.

# %%
Future Steps:

# %% [markdown]
# I am trying to learn how to do buttons with HTML only as I know how to do them with flask, but not with HTML. I want to do them in a way like my past portfolio where you click on a picture and it takes you to another page with several examples of this work. I also was not sure if we could add different things from past jobs to practice with, as the assignment specified to do this with one assignment from last semester. When we get more to add, this will definitely allow me to choose more towards the style and possibly be able to do this.
